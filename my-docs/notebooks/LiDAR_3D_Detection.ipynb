# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# %%
# !conda create -n py38 python=3.8.10 -c conda-forge --override-channels -y

# %%
# !conda create -n py38 python=3.8.10 -c conda-forge --override-channels -y

# %%
# !python --version

# %%
# !git clone https://github.com/open-mmlab/OpenPCDet.git
# %cd OpenPCDet

# %%
# !git clone https://github.com/open-mmlab/OpenPCDet.git
# %cd OpenPCDet

# %%
# !python setup.py develop

# %% [markdown]
# ### This code upload the kitti datasets and unzip the folder

# %%
# !unzip -q /content/OpenPCDet/data/kitti/testing.zip -d /content/OpenPCDet/data/kitti/testing
# !unzip -q /content/OpenPCDet/data/kitti/training.zip -d /content/OpenPCDet/data/kitti/training

# %%
# !rm /content/OpenPCDet/data/kitti/training.zip
# !rm /content/OpenPCDet/data/kitti/testing.zip

# %%
# !mv /content/OpenPCDet/data/kitti/training/training/* \
    /content/OpenPCDet/data/kitti/training/
# !mv /content/OpenPCDet/data/kitti/testing/testing/* \
    /content/OpenPCDet/data/kitti/testing/

# %%
# !rm -r /content/OpenPCDet/data/kitti/training/training
# !rm -r /content/OpenPCDet/data/kitti/testing/testing

# %%
# !pip install open3d
# !pip install av2==0.2.0
# !pip install kornia==0.6.12
# !pip install spconv-cu120 sharedarray

# %%
# !python -m pcdet.datasets.kitti.kitti_dataset create_kitti_infos tools/cfgs/dataset_configs/kitti_dataset.yaml

# %%
# %cd tools

# %%
# !python train.py --cfg_file cfgs/kitti_models/pv_rcnn.yaml

# %%
# !python demo.py --cfg_file cfgs/kitti_models/pv_rcnn.yaml \
    --ckpt /content/OpenPCDet/output/kitti_models/pv_rcnn/default/ckpt/checkpoint_epoch_80.pth \
    --data_path /content/OpenPCDet/data/kitti/training/velodyne/000008.bin \
    --output_dir /content/output_results

# %%
# !python test.py \
    --cfg_file /content/OpenPCDet/tools/cfgs/kitti_models/pv_rcnn.yaml \
    --batch_size 4 \
    --ckpt /content/OpenPCDet/output/kitti_models/pv_rcnn/default/ckpt/checkpoint_epoch_80.pth
